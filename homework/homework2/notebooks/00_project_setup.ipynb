# %% [markdown]
# Environment and Config Check

# %%
from dotenv import load_dotenv
import numpy as np
import os
# Out:
# True

# %%
load_dotenv()  # looks for a .env file in the current and parent directories
# Out:
# True

# %%
if os.getenv("API_KEY"):
    print("API_KEY =", os.getenv("API_KEY"))
else:
    print("API_KEY is missing")
# Out:
# API_KEY = dummy_key_123

# %%
# Test NumPy
arr = np.array([6,3,9,5,7])
print("NumPy array:", arr)
print("Array mean:", arr.mean())
# Out:
# NumPy array: [6 3 9 5 7]
# Array mean: 6.0
