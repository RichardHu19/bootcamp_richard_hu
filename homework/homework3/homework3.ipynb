# %%
import numpy as np
# %pip install pandas
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
arr = np.array([100, 150, 200, 250, 300, 400, 500, 600, 700, 800, 900, 1000])

# %timeit [arr[i] / 2  for i in range(len(arr))]
# %timeit arr / 2
# Out:
# 1.4 μs ± 25.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 972 ns ± 40.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
df.read_csv('starter_data.csv', )
