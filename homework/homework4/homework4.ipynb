# %% [markdown]
# # Homework Starter — Stage 04: Data Acquisition and Ingestion
# Name:
# Date:
#
# ## Objectives
# - API ingestion with secrets in `.env`
# - Scrape a permitted public table
# - Validate and save raw data to `data/raw/`

# %%
# --- packages this notebook needs (uncomment and run once, then re-comment) ---
# !pip install pandas
# !pip install requests
# !pip install yfinance
# !pip install python-dotenv
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: pandas in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2026.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: requests in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests) (2026.7.22)
# Collecting yfinance
#   Downloading yfinance-1.6.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (4.15.0)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Downloading curl_cffi-0.16.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (17 kB)
# Collecting lxml>=4.9.0 (from yfinance)
#   Downloading lxml-6.1.2-cp310-cp310-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.16.5 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (2.2.6)
# Requirement already satisfied: pandas>=1.3.0 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (2.3.3)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (4.11.3)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-7.36.0-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Requirement already satisfied: pytz>=2022.5 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (2026.3.post1)
# Requirement already satisfied: requests>=2.31 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from yfinance) (2.34.2)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-16.1.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from curl_cffi>=0.15->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2024.2.2 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from curl_cffi>=0.15->yfinance) (2026.7.22)
# Requirement already satisfied: pycparser in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2026.3)
# Requirement already satisfied: six>=1.5 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.7.0)
# Downloading yfinance-1.6.0-py3-none-any.whl (148 kB)
# Downloading curl_cffi-0.16.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 4.0 MB/s  0:00:03 eta 0:00:01
# Downloading lxml-6.1.2-cp310-cp310-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 4.2 MB/s  0:00:01 eta 0:00:01
# Using cached multitasking-0.0.13-py3-none-any.whl (16 kB)
# Downloading peewee-4.3.0-py3-none-any.whl (179 kB)
# Downloading protobuf-7.36.0-cp310-abi3-manylinux2014_x86_64.whl (340 kB)
# Downloading websockets-16.1.1-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (186 kB)
# Installing collected packages: multitasking, websockets, protobuf, peewee, lxml, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [yfinance]6/7 [yfinance]]]
# Successfully installed curl_cffi-0.16.0 lxml-6.1.2 multitasking-0.0.13 peewee-4.3.0 protobuf-7.36.0 websockets-16.1.1 yfinance-1.6.0
# Requirement already satisfied: python-dotenv in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: beautifulsoup4 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from beautifulsoup4) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/rhu/miniconda3/envs/bootcamp_env/lib/python3.10/site-packages (from beautifulsoup4) (4.16.0)

# %%
# --- files this notebook needs (run me first - I only report, I change nothing) ---
from pathlib import Path

ROOT = Path.cwd()          # notebooks are meant to be run from their own folder
CHECKS = [
    (".env", "NEEDED", "YOU create this: copy .env.example to .env. Missing = no error, but the config demo silently shows nothing"),
    (".env.example", "NEEDED", "shipped with this stage - the template you copy to .env"),
]

print(f"Looking in: {ROOT}\n")
missing = 0
for rel, kind, note in CHECKS:
    here = (ROOT / rel).exists()
    if not here and kind == "NEEDED":
        missing += 1
    print(f"  [{'OK ' if here else 'MISS'}]  {kind:<8}  {rel:<34}  {note}")

if missing:
    print(f"\n{missing} needed file(s) missing. Put them at the paths above, relative to:\n  {ROOT}")
    print("If that folder looks wrong, you are running the notebook from the wrong place.")
else:
    print("\nAll needed files present.")
# Out:
# Looking in: /home/rhu/bootcamp_richard_hu/homework/homework4
#
#   [OK ]  NEEDED    .env                                YOU create this: copy .env.example to .env. Missing = no error, but the config demo silently shows nothing
#   [OK ]  NEEDED    .env.example                        shipped with this stage - the template you copy to .env
#
# All needed files present.

# %%
import os, pathlib, datetime as dt
import requests
import pandas as pd
from bs4 import BeautifulSoup
from dotenv import load_dotenv

RAW = pathlib.Path('data/raw'); RAW.mkdir(parents=True, exist_ok=True)
load_dotenv(); print('ALPHAVANTAGE_API_KEY loaded?', bool(os.getenv('ALPHAVANTAGE_API_KEY')))
# Out:
# ALPHAVANTAGE_API_KEY loaded? True

# %% [markdown]
# ## Helpers (use or modify)

# %%
def ts():
    return dt.datetime.now().strftime('%Y%m%d-%H%M%S')

def save_csv(df: pd.DataFrame, prefix: str, **meta):
    mid = '_'.join([f"{k}-{v}" for k,v in meta.items()])
    path = RAW / f"{prefix}_{mid}_{ts()}.csv"
    df.to_csv(path, index=False)
    print('Saved', path)
    return path

def validate(df: pd.DataFrame, required):
    missing = [c for c in required if c not in df.columns]
    return {'missing': missing, 'shape': df.shape, 'na_total': int(df.isna().sum().sum())}

# %% [markdown]
# ## Part 1 — API Pull (Required)
# Choose an endpoint (e.g., Alpha Vantage or use `yfinance` fallback).

# %%
SYMBOL = 'SPY'
USE_ALPHA = bool(os.getenv('ALPHAVANTAGE_API_KEY'))
if USE_ALPHA:
    url = 'https://www.alphavantage.co/query'
    params = {'function':'TIME_SERIES_DAILY','symbol':SYMBOL,'outputsize':'compact','apikey':os.getenv('ALPHAVANTAGE_API_KEY')}
    r = requests.get(url, params=params, timeout=30)
    r.raise_for_status()
    js = r.json()
    # Alpha Vantage answers 200 OK with a prose blob when the free daily cap (25 calls)
    # is hit, so check for the series rather than trusting the status code.
    key = [k for k in js if 'Time Series' in k]
    if not key:
        print('Alpha Vantage returned no series:', str(list(js.values())[0])[:150])
        USE_ALPHA = False

if USE_ALPHA:
    df_api = pd.DataFrame(js[key[0]]).T.reset_index().rename(columns={'index':'date','4. close':'close'})[['date','close']]
    df_api['date'] = pd.to_datetime(df_api['date']); df_api['close'] = pd.to_numeric(df_api['close'])

if not USE_ALPHA:
    import yfinance as yf
    df_api = yf.download(SYMBOL, period='3mo', interval='1d', auto_adjust=False,
                         multi_level_index=False).reset_index()[['Date','Close']]
    df_api.columns = ['date','close']

v_api = validate(df_api, ['date','close']); v_api
# Out:
# {'missing': [], 'shape': (100, 2), 'na_total': 0}

# %%
df_api
# Out:
#          date   close
# 0  2026-08-21  765.72
# 1  2026-08-20  762.60
# 2  2026-08-19  769.06
# 3  2026-08-18  767.45
# 4  2026-08-17  772.67
# ..        ...     ...
# 95 2026-04-07  659.22
# 96 2026-04-06  658.93
# 97 2026-04-02  655.83
# 98 2026-04-01  655.24
# 99 2026-03-31  650.34
#
# [100 rows x 2 columns]

# %%
_ = save_csv(df_api.sort_values('date'), prefix='api', source='alpha' if USE_ALPHA else 'yfinance', symbol=SYMBOL)
# Out:
# Saved data/raw/api_source-alpha_symbol-SPY_20260822-164019.csv

# %% [markdown]
# ## Part 2 — Scrape a Public Table (Required)
# Replace `SCRAPE_URL` with a permitted page containing a simple table.

# %%
SCRAPE_URL = 'https://www.federalreserve.gov/releases/h15/'
headers = {'User-Agent':'AFE-Homework/1.0'}
try:
    resp = requests.get(SCRAPE_URL, headers=headers, timeout=30); resp.raise_for_status()
    soup = BeautifulSoup(resp.text, 'html.parser')
    rows = [[c.get_text(strip=True) for c in tr.find_all(['th','td'])] for tr in soup.find_all('tr')]
    header, *data = [r for r in rows if r]
    df_scrape = pd.DataFrame(data, columns=header)
except Exception as e:
    print('Scrape failed, using inline demo table:', e)
    html = '<table><tr><th>Ticker</th><th>Price</th></tr><tr><td>AAA</td><td>101.2</td></tr></table>'
    soup = BeautifulSoup(html, 'html.parser')
    rows = [[c.get_text(strip=True) for c in tr.find_all(['th','td'])] for tr in soup.find_all('tr')]
    header, *data = [r for r in rows if r]
    df_scrape = pd.DataFrame(data, columns=header)

if 'Price' in df_scrape.columns:
    df_scrape['Price'] = pd.to_numeric(df_scrape['Price'], errors='coerce')
v_scrape = validate(df_scrape, list(df_scrape.columns)); v_scrape
# Out:
# {'missing': [], 'shape': (39, 6), 'na_total': 4}

# %%
df_scrape
# Out:
#                               Instruments       2026Aug14 2026Aug17 2026Aug18  \
# 0            Federal funds (effective)123            3.63      3.63      3.63
# 1                    Commercial Paper3456
# 2                            Nonfinancial
# 3                                 1-month            3.72      3.71      3.66
# 4                                 2-month            3.74      3.73      3.69
# 5                                 3-month            n.a.      n.a.      3.69
# 6                               Financial
# 7                                 1-month            n.a.      n.a.      n.a.
# 8                                 2-month            3.76      n.a.      n.a.
# 9                                 3-month            3.82      3.78      3.79
# 10                     Bank prime loan237            6.75      6.75      6.75
# 11       Discount window primary credit28            3.75      3.75      3.75
# 12             U.S. government securities
# 13    Treasury bills (secondary market)34
# 14                                 4-week            3.64      3.64      3.63
# 15                                3-month            3.71      3.72      3.71
# 16                                6-month            3.79      3.79      3.78
# 17                                 1-year            3.81      3.82      3.82
# 18           Treasury constant maturities
# 19                               Nominal9
# 20                                1-month            3.79      3.79      3.78
# 21                                3-month            3.86      3.87      3.86
# 22                                6-month            3.95      3.95      3.94
# 23                                 1-year            3.98      4.00      3.99
# 24                                 2-year            4.17      4.19      4.19
# 25                                 3-year            4.24      4.25      4.26
# 26                                 5-year            4.36      4.38      4.37
# 27                                 7-year            4.51      4.54      4.53
# 28                                10-year            4.68      4.72      4.71
# 29                                20-year            5.25      5.30      5.28
# 30                                30-year            5.25      5.31      5.28
# 31                    Inflation indexed10
# 32                                 5-year            2.12      2.13      2.10
# 33                                 7-year            2.25      2.27      2.24
# 34                                10-year            2.41      2.44      2.41
# 35                                20-year            2.78      2.84      2.81
# 36                                30-year            3.00      3.06      3.03
# 37  Inflation-indexed long-term average11            2.97      3.03      3.00
# 38                                   n.a.  Not available.      None      None
#
#    2026Aug19 2026Aug20
# 0       3.63      3.63
# 1
# 2
# 3       3.67      3.71
# 4       3.69      3.73
# 5       3.68      n.a.
# 6
# 7       3.71      n.a.
# 8       n.a.      3.74
# 9       3.84      3.80
# 10      6.75      6.75
# 11      3.75      3.75
# 12
# 13
# 14      3.62      3.65
# 15      3.71      3.71
# 16      3.78      3.78
# 17      3.82      3.82
# 18
# 19
# 20      3.77      3.80
# 21      3.86      3.87
# 22      3.94      3.94
# 23      4.00      3.99
# 24      4.19      4.19
# 25      4.25      4.26
# 26      4.35      4.39
# 27      4.48      4.53
# 28      4.65      4.69
# 29      5.17      5.20
# 30      5.19      5.23
# 31
# 32      2.07      2.05
# 33      2.19      2.18
# 34      2.35      2.35
# 35      2.72      2.73
# 36      2.94      2.95
# 37      2.91      2.91
# 38      None      None

# %%
_ = save_csv(df_scrape, prefix='scrape', site='federal_reserve', table='markets')
# Out:
# Saved data/raw/scrape_site-federal_reserve_table-markets_20260822-170409.csv

# %% [markdown]
# ## Documentation
# - API Source: (URL/endpoint/params)
# - Scrape Source: (URL/table description)
# - Assumptions & risks: (rate limits, selector fragility, schema changes)
# - Confirm `.env` is not committed.
